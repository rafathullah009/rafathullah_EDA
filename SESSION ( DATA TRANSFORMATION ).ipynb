# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## $STEP$ -$1$

# %% [markdown]
# $ Read$ $the$ $data $

# %% [markdown]
# $ Exponential$-$data$

# %%
path=r"C:\Users\rocks\Documents\file handling\Visadataset.csv"

# %%
exp_data=np.random.exponential(size=10000)
exp_data[:10]
# Out:
# array([0.23992157, 0.55387418, 0.8928502 , 0.59393918, 0.08780504,
#        0.54681602, 0.18421664, 0.19057826, 1.36434222, 1.94617371])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# $NORM$-$DATA$

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([  3.,  12.,  58., 125., 223., 250., 185.,  96.,  37.,  11.]),
#  array([-3.28211423, -2.65868767, -2.0352611 , -1.41183454, -0.78840797,
#         -0.16498141,  0.45844515,  1.08187172,  1.70529828,  2.32872484,
#          2.95215141]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $STEP$ -3

# %% [markdown]
# Log Transformatiom

# %%
x=2
import numpy as np
np.log(2)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([-1.4274432 , -0.59081772, -0.11333646, -0.52097836, -2.43263638,
#        -0.60364288, -1.69164284, -1.65769235,  0.31067242,  0.66586525])

# %%
exp_data[:10]
# Out:
# array([0.23992157, 0.55387418, 0.8928502 , 0.59393918, 0.08780504,
#        0.54681602, 0.18421664, 0.19057826, 1.36434222, 1.94617371])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                       bins=40,
                       label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(log_data,
                       bins=40,
                       label='Log Transformation')

plt.legend()
plt.show()

# %% [markdown]
# $step$-4

# %% [markdown]
# ## Reciprocal transformation

# %%
x=3
np.reciprocal(x)
# Out:
# 0

# %%
rec_data=np.reciprocal(exp_data)

# %%
exp_data,rec_data
# Out:
# (array([0.23992157, 0.55387418, 0.8928502 , ..., 0.40024077, 0.37520977,
#         2.32844516]),
#  array([4.16802876, 1.80546418, 1.12000871, ..., 2.49849612, 2.66517579,
#         0.42947114]))

# %%
4/0.23
# Out:
# 17.391304347826086

# %%
rec_data=np.reciprocal(exp_data)
plt.hist(rec_data,bins=40,label='Reciprocal Data')
plt.legend()
plt.show()

# %%
exp_data[:2]
# Out:
# array([0.23992157, 0.55387418])

# %% [markdown]
# $step$-5

# %% [markdown]
# ## square root transformation

# %%
print(25**2)
print(25**(1/2))
print(np.sqrt(25))
# Out:
# 625
# 5.0
# 5.0

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                       bins=40,
                       label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,
                       bins=40,
                       label='Square root Transformation')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.histplot(sqrt_data)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# $STEP$-6

# %% [markdown]
# ## POWER TRANSFORMER

# %%
exp_data
# Out:
# array([0.23992157, 0.55387418, 0.8928502 , ..., 0.40024077, 0.37520977,
#        2.32844516])

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_data=pt.fit([exp_data]).transform([exp_data])

# %%
pt_data
# Out:
# array([[-2.77555756e-17,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00, -1.11022302e-16,  0.00000000e+00]])

# %%
plt.hist(pt_data[0])
plt.show()

# %%
pt=PowerTransformer()
